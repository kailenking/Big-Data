# %%
import pandas as pd

# %%
file = open('/Users/kailenking/Downloads/homework2/fetal_health.csv')

# %%
file
# Out:
# <_io.TextIOWrapper name='/Users/kailenking/Downloads/homework2/fetal_health.csv' mode='r' encoding='UTF-8'>

# %%
import csv

# %%
df = pd.read_csv (r'/Users/kailenking/Downloads/homework2/fetal_health.csv')
print (df)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
train = df.head(n=1500)
train.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     1500.000000    1500.000000     1500.000000           1500.000000
# mean       133.692000       0.003077        0.012531              0.003771
# std         10.438156       0.003806        0.055081              0.002884
# min        112.000000       0.000000        0.000000              0.000000
# 25%        125.000000       0.000000        0.000000              0.001000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        142.000000       0.005000        0.004000              0.006000
# max        159.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          1500.000000           1500.000000               1500.000000
# mean              0.001284              0.000001                  0.000101
# ...

# %%
testnum = 2126 - 1500
print(testnum)
# Out:
# 626

# %%
test = df.iloc[1500:]
test.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count      626.000000     626.000000      626.000000            626.000000
# mean       132.373802       0.003420        0.002171              0.005792
# std          8.168087       0.003997        0.007198              0.002584
# min        106.000000       0.000000        0.000000              0.000000
# 25%        130.000000       0.000000        0.000000              0.004000
# 50%        133.000000       0.002000        0.000000              0.006000
# 75%        138.000000       0.006000        0.002000              0.008000
# max        160.000000       0.017000        0.054000              0.014000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count            626.00000            626.000000                626.000000
# mean               0.00334              0.000008                  0.000296
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.tree import DecisionTreeRegressor
DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
DT_predict = DT_model.predict(X_test) #Predictions on Testing data
print(DT_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6k/c2cjkwg92_3bh964qg2g0c1r0000gn/T/ipykernel_54817/3653838279.py in <module>
#       1 from sklearn.tree import DecisionTreeRegressor
# ----> 2 DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
#       3 DT_predict = DT_model.predict(X_test) #Predictions on Testing data
#       4 print(DT_predict)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.metrics import confusion_matrix
>>> y_true = [2, 0, 2, 2, 0, 1]
>>> y_pred = [0, 0, 2, 2, 0, 2]
>>> confusion_matrix(y_true, y_pred)
# Out:
# array([[2, 0, 0],
#        [0, 0, 1],
#        [1, 0, 2]])

# %%
 from sklearn.metrics import precision_score
>>> y_true = [0, 1, 2, 0, 1, 2]
>>> y_pred = [0, 2, 1, 0, 0, 1]
 precision_score(y_true, y_pred, average='macro')
# Out:
# 0.2222222222222222

# %%
from sklearn.metrics import recall_score
>>> y_true = [0, 1, 2, 0, 1, 2]
>>> y_pred = [0, 2, 1, 0, 0, 1]
>>> recall_score(y_true, y_pred, average='macro')
# Out:
# 0.3333333333333333

# %%
 from sklearn.metrics import f1_score
>>> y_true = [0, 1, 2, 0, 1, 2]
>>> y_pred = [0, 2, 1, 0, 0, 1]
>>> f1_score(y_true, y_pred, average='macro')
# Out:
# 0.26666666666666666

# %%
from sklearn.metrics import matthews_corrcoef
>>> y_true = [+1, +1, +1, -1]
>>> y_pred = [+1, -1, +1, +1]
>>> matthews_corrcoef(y_true, y_pred)
# Out:
# -0.3333333333333333

# %%
import numpy as np
X = np.random.rand(1000,2)
y = np.random.randint(0, 5, 1000)

from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier().fit(X, y)
tree.feature_importances_
# Out:
# array([0.49752717, 0.50247283])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

plt.xticks(x_pos, x)

plt.show()

# %%
file1 = open('/Users/kailenking/Downloads/homework2/adult.data')

# %%
import pandas as pd
df1 = pd.read_csv (r'/Users/kailenking/Downloads/homework2/adult.data')
print (df1)
train1 = df1
train1.describe()
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
file2 = open('/Users/kailenking/Downloads/homework2/adult.test')
df2 = pd.read_csv (r'/Users/kailenking/Downloads/homework2/adult.test')
print(df2)
test1 = df2
test1.describe()
# Out:
#        25        Private   226802           11th   7        Never-married  \
# 0      38        Private    89814        HS-grad   9   Married-civ-spouse
# 1      28      Local-gov   336951     Assoc-acdm  12   Married-civ-spouse
# 2      44        Private   160323   Some-college  10   Married-civ-spouse
# 3      18              ?   103497   Some-college  10        Never-married
# 4      34        Private   198693           10th   6        Never-married
# ...    ..            ...      ...            ...  ..                  ...
# 16275  39        Private   215419      Bachelors  13             Divorced
# 16276  64              ?   321403        HS-grad   9              Widowed
# 16277  38        Private   374983      Bachelors  13   Married-civ-spouse
# 16278  44        Private    83891      Bachelors  13             Divorced
# 16279  35   Self-emp-inc   182148      Bachelors  13   Married-civ-spouse
#
#         Machine-op-inspct        Own-child                Black     Male  \
# ...

# %%
def encode_and_bind(original_dataframe, features_to_encode):
    dummies = pd.get_dummies(original_dataframe[features_to_encode])
    res = pd.concat([dummies, original_dataframe], axis=1)
    res = res.drop(features_to_encode, axis=1)
    return(res)
X_train_encoded = encode_and_bind(X_train, features_to_encode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6k/c2cjkwg92_3bh964qg2g0c1r0000gn/T/ipykernel_54817/1135560560.py in <module>
#       4     res = res.drop(features_to_encode, axis=1)
#       5     return(res)
# ----> 6 X_train_encoded = encode_and_bind(X_train, features_to_encode)
#
# NameError: name 'X_train' is not defined

# %%
adult_train = 2022

adult_train_set = input("What is the set? ")

#convert the raw user input to an int using the int() function and store in new variable
adult_test_set = int(adult_train_set)

#subtract the current year from the converted user input
adult_train_set = adult_train - adult_test_set

print(adult_train_set)
# Out:
# What is the set? 2
# 2020

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
metrics.plot_roc_curve(clf, X_test, y_test) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6k/c2cjkwg92_3bh964qg2g0c1r0000gn/T/ipykernel_54817/3627289576.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 from sklearn import metrics
# ----> 3 metrics.plot_roc_curve(clf, X_test, y_test)
#       4 plt.show()
#
# NameError: name 'clf' is not defined

# %%
import GridSearchCV
hyperparameters = { 'randomforestregressor__max_features' : ['auto', 'sqrt', 'log2'],
                  'randomforestregressor__max_depth': [None, 5, 3, 1]}
 
clf = GridSearchCV(pipeline, hyperparameters, cv=10)
 
clf.fit(X_train, y_train)

pred = clf.predict(X_test)
print (r2_score(y_test, pred))
print (mean_squared_error(y_test, pred))

print(clf)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/6k/c2cjkwg92_3bh964qg2g0c1r0000gn/T/ipykernel_54817/984618301.py in <module>
# ----> 1 import GridSearchCV
#       2 hyperparameters = { 'randomforestregressor__max_features' : ['auto', 'sqrt', 'log2'],
#       3                   'randomforestregressor__max_depth': [None, 5, 3, 1]}
#       4
#       5 clf = GridSearchCV(pipeline, hyperparameters, cv=10)
#
# ModuleNotFoundError: No module named 'GridSearchCV'

# %%
import numpy as np

X = np.linspace(start=0, stop=10, num=1_000).reshape(-1, 1)
y = np.squeeze(X * np.sin(X))
import matplotlib.pyplot as plt

plt.plot(X, y, label=r"$f(x) = x \sin(x)$", linestyle="dotted")
plt.legend()
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
_ = plt.title("True generative process")

rng = np.random.RandomState(1)
training_indices = rng.choice(np.arange(y.size), size=6, replace=False)
X_train, y_train = X[training_indices], y[training_indices]

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

kernel = 1 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e2))
gaussian_process = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
gaussian_process.fit(X_train, y_train)
gaussian_process.kernel_

mean_prediction, std_prediction = gaussian_process.predict(X, return_std=True)

plt.plot(X, y, label=r"$f(x) = x \sin(x)$", linestyle="dotted")
plt.scatter(X_train, y_train, label="Observations")
plt.plot(X, mean_prediction, label="Mean prediction")
plt.fill_between(
    X.ravel(),
    mean_prediction - 1.96 * std_prediction,
    mean_prediction + 1.96 * std_prediction,
    alpha=0.5,
    label=r"95% confidence interval",
)
plt.legend()
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
_ = plt.title("Gaussian process regression on noise-free dataset")

# %%
file = open('/Users/kailenking/Downloads/homework2/superconductors.csv')

# %%
df3 = pd.read_csv (r'/Users/kailenking/Downloads/homework2/superconductors.csv')
print (df3)
train3 = df3.head(n=17010)
train3.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# ...                   ...               ...                   ...
# 21258                   4        106.957877             53.095769
# 21259                   5         92.266740             49.021367
# 21260                   2         99.663190             95.609104
# 21261                   2         99.663190             97.095602
# 21262                   3         87.468333             86.858500
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0              66.361592              36.116612             1.181795
# ...

# %%
test3 = df3.iloc[17010:]
test3.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count         4253.000000       4253.000000           4253.000000
# mean             3.997178         83.586383             76.999068
# std              1.207920         29.728771             29.755796
# min              1.000000          6.941000              6.423452
# 25%              3.000000         63.457667             59.542100
# 50%              4.000000         78.481359             72.796985
# 75%              5.000000         96.227767             85.902954
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count        4253.000000            4253.000000          4253.000000
# mean           69.655099              64.614251             1.166224
# std            31.030604              32.035109             0.315563
# min             5.320573               1.960849             0.000000
# ...

# %%
mport math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

# Font for figure for publishing
font_axis_publish = {
        'color':  'black',
        'weight': 'bold',
        'size': 22,
        }
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 16

# Read in data
pred_vals = pd.read_csv("pred.csv", header=0, names=['Index','Pred'])
gt_vals = pd.read_csv("gt.csv",header=0, names=['Index','GT'])

# Plot Figures
fignow = plt.figure(figsize=(8,8))

x = gt_vals['GT']
y = pred_vals['Pred']

## find the boundaries of X and Y values
bounds = (min(x.min(), y.min()) - int(0.1 * y.min()), max(x.max(), y.max())+ int(0.1 * y.max()))

# Reset the limits
ax = plt.gca()
ax.set_xlim(bounds)
ax.set_ylim(bounds)
# Ensure the aspect ratio is square
ax.set_aspect("equal", adjustable="box")

plt.plot(x,y,"o", alpha=0.5 ,ms=10, markeredgewidth=0.0)

ax.plot([0, 1], [0, 1], "r-",lw=2 ,transform=ax.transAxes)

# Calculate Statistics of the Parity Plot 
mean_abs_err = np.mean(np.abs(x-y))
rmse = np.sqrt(np.mean((x-y)**2))
rmse_std = rmse / np.std(y)
z = np.polyfit(x,y, 1)
y_hat = np.poly1d(z)(x)

text = f"$\: \: Mean \: Absolute \: Error \: (MAE) = {mean_abs_err:0.3f}$ \n $ Root \: Mean \: Square \: Error \: (RMSE) = {rmse:0.3f}$ \n $ RMSE \: / \: Std(y) = {rmse_std :0.3f}$ \n $R^2 = {r2_score(y,y_hat):0.3f}$"

plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=14, verticalalignment='top')

# Title and labels 
plt.title("Parity Plot", fontdict=font_axis_publish)
plt.xlabel('Ground Truth', fontdict=font_axis_publish)
plt.ylabel('Prediction', fontdict=font_axis_publish)

# Save the figure into 300 dpi
fignow.savefig("parityplot.png",format = "png",dpi=300,bbox_inches='tight')
# Out:
#   File "/var/folders/6k/c2cjkwg92_3bh964qg2g0c1r0000gn/T/ipykernel_54817/1533026689.py", line 1
#     mport math
#           ^
# SyntaxError: invalid syntax

# %%
from sklearn.metrics import r2_score
>>> y_true = [3, -0.5, 2, 7]
>>> y_pred = [2.5, 0.0, 2, 8]
>>> r2_score(y_true, y_pred)
# Out:
# 0.9486081370449679

# %%
from sklearn.metrics import mean_absolute_error
>>> y_true = [3, -0.5, 2, 7]
>>> y_pred = [2.5, 0.0, 2, 8]
>>> mean_absolute_error(y_true, y_pred)
# Out:
# 0.5

# %%
from sklearn.metrics import mean_squared_error
>>> y_true = [3, -0.5, 2, 7]
>>> y_pred = [2.5, 0.0, 2, 8]
>>> mean_squared_error(y_true, y_pred)
# Out:
# 0.375
